# %% [markdown]
# Modules->Package->Library

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sb

# %% [markdown]
#  what is PyPI?

# %%
import my_module as mm
mm.say_hello("Vishy")
# Out:
# Hello Vishy

# %%
from my_module import person1
print(person1["age"])
# Out:
# 16

# %%
from math import sqrt, pi, factorial
square_root = sqrt
num = 81
square_root(num)
# Out:
# 9.0

# %% [markdown]
# WAP to add two numbers and run it throw CLI

# %%
def max(num):
    pass
