# %%
a = 99
b = 139
print(a+b)
# Out:
# 238

# %%
print("Hello")
# Out:
# Hello

# %%
print(b-a)
# Out:
# 40

# %%
print(a*b)
# Out:
# 13761

# %%
print(a/b)
# Out:
# 0.7122302158273381

# %%
print(a//b)
# Out:
# 0

# %%
print(10**2)
# Out:
# 100

# %%
print(-10//3)
# Out:
# -4

# %%
print(2**-1)
# Out:
# 0.5

# %%
print(7**0)
# Out:
# 1

# %%
print(151%7)
# Out:
# 4

# %%
x = 15
y = 13
print(x==y)
# Out:
# False

# %%
print(x<y)
# Out:
# False

# %%
print(x>y)
# Out:
# True

# %%
print(x!=y)
# Out:
# True

# %%
print(x<=y)
# Out:
# False

# %%
print(x>=y)
# Out:
# True

# %%
v = 15
u = 5

# %%
a1 = 12
a1 += 1
print(a1)
# Out:
# 13

# %%
a1 = 10
a1 -= 2
print(a1)
# Out:
# 8

# %%
a1 = 17
a1 *= 4
print(a1)
# Out:
# 68

# %%
a1 = 56
a1 /= 2 
print(a1)
# Out:
# 28.0

# %%
a1 = 67
a1//=2
print(a1)
# Out:
# 33

# %%
a1 = 5
a1**=2
print(a1)
# Out:
# 25

# %%
a1 = 91
a1 %= 3
print(a1)
# Out:
# 1

# %%
a, b = 2,10
print(a<5 and b > 19)
# Out:
# False

# %%
print(a<5 or b > 19)
# Out:
# True

# %%
is_al = True
print(not is_al)
# Out:
# False
