# %%
str1 = "Good Morning "
str2 = "Everyone"

# %%
print(str1+str2)
# Out:
# Good Morning Everyone

# %%
str3 = str1+str2
print(len(str3))
# Out:
# 21

# %%
print("good"*3)
# Out:
# goodgoodgood

# %%
str4 = "Python is Easy!!!"
print(str4[0])
# Out:
# P

# %% [markdown]
# unicode strigs : Prefixing the string with small u or U python allows you to specify unicode text

# %% [markdown]
# Escape Sequence :It's combination of characters that is translated in different characters or sequence of character that may be difficult or impossible to represent directly

# %%
print("The Boy replied,\"My name is Aditya\"")
# Out:
# The Boy replied,"My name is Aditya"

# %%
print("The Boy replied,\n\"My name is Aditya\"")
# Out:
# The Boy replied,
# "My name is Aditya"

# %%
print("The Boy replied,\t\"My name is Aditya\"")
# Out:
# The Boy replied,	"My name is Aditya"

# %%
print("The Boy replied,\ My name is Aditya")
# Out:
# The Boy replied,\ My name is Aditya
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\VISHESH BANNA\AppData\Local\Temp\ipykernel_16616\2311175047.py:1: SyntaxWarning: invalid escape sequence '\ '
#   print("The Boy replied,\ My name is Aditya")

# %% [markdown]
# when specifying the string with single back slash at end of line it indicates string is continued in the next line but no new line is added otherwise

# %%
print("\\")
# Out:
# \

# %%
print("\'")
print("\"")
# Out:
# '
# "

# %%
print("Hello \nworld")
# Out:
# Hello
# world

# %%
print("Hello\tworld")
# Out:
# Hello	world

# %%
print("\056")
# Out:
# .

# %%
print("\x2E")
# Out:
# .

# %%
print(int("11011", 2))
# Out:
# 27

# %%
print(oct(51))
# Out:
# 0o63

# %%
x = 10
y = 4

# %%
print(x&y)
# Out:
# 0

# %%
print(x|y)
# Out:
# 14

# %%
print(x^y)
# Out:
# 14

# %%
print(~x)
# Out:
# -11

# %%
print(~y)
# Out:
# -5
