# %% [markdown]
# print 4X6 star pattern

# %%
for i in range(0,4):
    for j in range(0,6):
        print("*",end="")
    print()
# Out:
# ******
# ******
# ******
# ******

# %%
for j in range(5):
    for i in range(5):
        if i <= j:
            print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(5):
    for j in range(5):
        if i <= j:
            print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
n=5
for i in range(n):
    for k in range(i,n):
        print(" ",end="")
    for j in range(i+1):
        print(j+1,end="")
    print()
# Out:
#      1
#     12
#    123
#   1234
#  12345

# %%
n=5
for i in range(n):
    for j in range(n):
